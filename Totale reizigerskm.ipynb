# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Totale_reizigerskilometers.csv", delimiter=';', decimal=',', skiprows=5)
tot = data[data['Vervoerwijzen'].isin(['Totaal'])].transpose().iloc[2:, :]
car = data[ data['Vervoerwijzen'].isin(['Auto (bestuurder)']) ].transpose().iloc[2:, :]
car2 = data[ data['Vervoerwijzen'].isin(['Auto (passagier)']) ].transpose().iloc[2:, :]
train = data[ data['Vervoerwijzen'].isin(['Trein']) ].transpose().iloc[2:, :]
tot.index = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
car.index = tot.index
car2.index = tot.index
train.index = tot.index
# display(test)
# display(car[13]+car2[26])
# display(train[39])
plt.figure(figsize=(20, 20))
plt.subplot(3,1,1)
plt.plot(test[0])
plt.subplot(3,1,2)
plt.plot(car[13]+car2[26])
plt.subplot(3,1,3)
plt.plot(train[39])
