# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data2 = pd.read_csv("Traffic_motor_vehicles_21102024_112422.csv", delimiter=';', decimal='.', index_col='Periods')
plt.plot(data2[data2['Types of vehicle'].isin(['Total motor vehicles'])]['Kilometres in the Netherlands/Total kilometres in the Netherlands (million km)'])
