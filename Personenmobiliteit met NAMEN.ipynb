# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("mobility_data.csv", delimiter=';', index_col='ID')
keys = pd.read_csv("mobility_info.csv", skiprows=19, usecols=['Key', 'Title', 'Description'], delimiter=';')
mode = dict(zip(keys['Key'], keys['Title']))
data = data.replace(mode)
display(data)
# Out:
#         Populatie         Vervoerwijzen                 KenmerkenVerplaatsing  \
# ID
# 0           10000                Totaal                                Totaal
# 1           10000                Totaal                                Totaal
# 2           10000                Totaal                                Totaal
# 3           10000                Totaal                                Totaal
# 4           10000                Totaal                                Totaal
# ...           ...                   ...                                   ...
# 126715      20100  Overige vervoerwijze  Vertrektijdstip: avond 18 tot 24 uur
# 126716      20100  Overige vervoerwijze  Vertrektijdstip: avond 18 tot 24 uur
# 126717      20100  Overige vervoerwijze  Vertrektijdstip: avond 18 tot 24 uur
# 126718      20100  Overige vervoerwijze  Vertrektijdstip: avond 18 tot 24 uur
# 126719      20100  Overige vervoerwijze  Vertrektijdstip: avond 18 tot 24 uur
#
# ...
